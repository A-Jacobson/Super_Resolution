# %%
from datasets import SuperResolutionDataset
from torchvision import transforms
from models import FSRCNN
from torch.autograd import Variable
from torch.optim import Adam
from torch import nn

from train_utils import prep_img, fit, save_checkpoint
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-0e2e95537264> in <module>()
# ----> 1 from datasets import SuperResolutionDataset
#       2 from torchvision import transforms
#       3 from models import FSRCNN
#       4 from torch.autograd import Variable
#       5 from torch.optim import Adam
#
# ImportError: cannot import name 'SuperResolutionDataset'

# %%
path = '/home/austin/data/ILSVRC/test'

# %%
trans = transforms.ToTensor()
to_pil = transforms.ToPILImage()

# %%
srdata = SuperResolutionDataset(path, transforms=trans, small_size=(78, 78), large_size=(220, 220))

# %%
fsrcnn = FSRCNN()
fsrcnn.cuda()
# Out:
# FSRCNN (
#   (conv1): ConvBlock (
#     (conv1): Conv2d(3, 56, kernel_size=(5, 5), stride=(1, 1))
#     (prelu): PReLU (1)
#   )
#   (conv2): ConvBlock (
#     (conv1): Conv2d(56, 12, kernel_size=(1, 1), stride=(1, 1))
#     (prelu): PReLU (1)
#   )
#   (conv3): ConvBlock (
#     (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (prelu): PReLU (1)
#   )
#   (conv4): ConvBlock (
#     (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (prelu): PReLU (1)
#   )
#   (conv5): ConvBlock (
#     (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (prelu): PReLU (1)
#   )
#   (conv6): ConvBlock (
#     (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (prelu): PReLU (1)
#   )
#   (conv7): ConvBlock (
#     (conv1): Conv2d(12, 56, kernel_size=(1, 1), stride=(1, 1))
#     (prelu): PReLU (1)
#   )
# ...

# %%
optimizer = Adam(fsrcnn.parameters())
criterion = nn.MSELoss()

# %%
to_pil(srdata[0][1])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F0A561DE7F0>

# %%
history = fit(fsrcnn, srdata, criterion, optimizer, batch_size=64, shuffle=True)
# Out:
# Train on 5500 samples
# [loss: 0.0531 ]
# defaultdict(list, {'loss': [0.05306915263103884]})

# %%
out = fsrcnn(prep_img(srdata[0][0]))
to_pil(out.data.cpu()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F0A5407AAC8>

# %%
history = fit(fsrcnn, srdata, criterion, optimizer, batch_size=64, shuffle=True, nb_epoch=5)
# Out:
# Train on 5500 samples
# [loss: 0.0232 ]
# [loss: 0.0215 ]
# [loss: 0.0211 ]
# [loss: 0.0208 ]
# [loss: 0.0180 ]
# defaultdict(list,
#             {'loss': [0.023190612319943515,
#               0.02154687460685192,
#               0.02106280679013147,
#               0.02082753900525182,
#               0.01799555985950107]})

# %%
out = fsrcnn(prep_img(srdata[0][0]))
to_pil(out.data.cpu()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F0A4F3D07B8>

# %%
history = fit(fsrcnn, srdata, criterion, optimizer, batch_size=64, shuffle=True, nb_epoch=5)
# Out:
# Train on 5500 samples
# [loss: 0.0163 ]
# [loss: 0.0161 ]
# [loss: 0.0160 ]
# [loss: 0.0159 ]
# [loss: 0.0159 ]
# defaultdict(list,
#             {'loss': [0.016259433896562387,
#               0.016111547614686018,
#               0.015968833161994468,
#               0.015914531023956315,
#               0.015863174106925726]})

# %%
out = fsrcnn(prep_img(srdata[0][0]))
to_pil(out.data.cpu()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F0A4F3ED710>

# %%
history = fit(fsrcnn, srdata, criterion, optimizer, batch_size=64, shuffle=True, nb_epoch=10)
# Out:
# Train on 5500 samples
# [loss: 0.0158 ]
# [loss: 0.0156 ]
# [loss: 0.0151 ]
# [loss: 0.0149 ]
# [loss: 0.0148 ]
# [loss: 0.0147 ]
# [loss: 0.0147 ]
# [loss: 0.0146 ]
# [loss: 0.0147 ]
# [loss: 0.0146 ]
# defaultdict(list,
#             {'loss': [0.01580562875714413,
#               0.015612247215887142,
#               0.015134836687858021,
#               0.014918292872607708,
#               0.014787542038099018,
#               0.014720119297677694,
#               0.014704464664032985,
#               0.014617758185797653,
#               0.014681097791465215,
#               0.01464777940147838]})

# %%
out = fsrcnn(prep_img(srdata[0][0]))
to_pil(out.data.cpu()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F0A4F35C9B0>

# %%
history = fit(fsrcnn, imagenet, criterion, optimizer, batch_size=64, shuffle=True, nb_epoch=50)
# Out:
# Train on 5500 samples
# [loss: 0.0146 ]
# [loss: 0.0145 ]
# [loss: 0.0144 ]
# [loss: 0.0144 ]
# [loss: 0.0144 ]
# [loss: 0.0143 ]
# [loss: 0.0143 ]
# [loss: 0.0142 ]
# [loss: 0.0142 ]
# [loss: 0.0141 ]
# [loss: 0.0141 ]
# [loss: 0.0141 ]
# [loss: 0.0140 ]
# [loss: 0.0140 ]
# [loss: 0.0139 ]
# [loss: 0.0139 ]
# [loss: 0.0139 ]
# [loss: 0.0139 ]
# [loss: 0.0139 ]
# [loss: 0.0138 ]
# [loss: 0.0139 ]
# [loss: 0.0137 ]
# [loss: 0.0137 ]
# [loss: 0.0138 ]
# [loss: 0.0137 ]
# [loss: 0.0137 ]
# [loss: 0.0136 ]
# [loss: 0.0136 ]
# [loss: 0.0136 ]
# [loss: 0.0136 ]
# [loss: 0.0135 ]
# [loss: 0.0135 ]
# [loss: 0.0136 ]
# [loss: 0.0135 ]
# [loss: 0.0135 ]
# [loss: 0.0134 ]
# [loss: 0.0134 ]
# [loss: 0.0134 ]
# [loss: 0.0134 ]
# [loss: 0.0134 ]
# [loss: 0.0133 ]
# [loss: 0.0133 ]
# [loss: 0.0133 ]
# [loss: 0.0133 ]
# [loss: 0.0132 ]
# [loss: 0.0133 ]
# [loss: 0.0132 ]
# [loss: 0.0133 ]
# [loss: 0.0133 ]
# [loss: 0.0132 ]
# defaultdict(list,
#             {'loss': [0.014605771620259729,
# ...

# %%
out = fsrcnn(prep_img(srdata[0][0]))
to_pil(out.data.cpu()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F0A1C00E9E8>

# %%
fit(fsrcnn, imagenet, criterion, optimizer, batch_size=64, shuffle=True, nb_epoch=20)
# Out:
# Train on 5500 samples
# [loss: 0.0132 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0130 ]
# [loss: 0.0131 ]
# [loss: 0.0131 ]
# [loss: 0.0130 ]
# [loss: 0.0130 ]
# [loss: 0.0130 ]
# [loss: 0.0130 ]
# [loss: 0.0131 ]
# [loss: 0.0130 ]
# [loss: 0.0130 ]
# [loss: 0.0131 ]
# [loss: 0.0129 ]
# defaultdict(list,
#             {'loss': [0.013188475612984148,
#               0.013124482554578504,
#               0.013136364573742761,
#               0.013119673605488484,
#               0.01309111708948432,
#               0.013131836678312962,
#               0.013089923848679592,
#               0.013063416859611522,
#               0.0130145663590452,
#               0.01306892930378401,
#               0.013093465137793574,
#               0.0129916662090393,
#               0.013025922700762749,
#               0.013027856906139574,
#               0.012982073467398105,
# ...

# %%
out = fsrcnn(prep_img(imagenet[0][0]))
to_pil(out.data.cpu()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7F09FF1A4A58>

# %%
save_checkpoint(fsrcnn.state_dict(), optimizer.state_dict(),'fsrcnn_91epoch.pth.tar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a0e5755dc8db> in <module>()
# ----> 1 save_checkpoint(fsrcnn.state_dict(), optimizer.state_dict(),'fsrcnn_91epoch.pth.tar')
#
# NameError: name 'save_checkpoint' is not defined
